# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/LARGE SCALE DATA PROCESSING/PROJECT/netfli.csv', na_values=['NA'])

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
data.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %%
data['user rating score'].fillna((data['user rating score'].mean()), inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          1000 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    1000 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004          82.000000                80
# 1          2006          84.094215                82
# 2          2016          98.000000                80
# 3          2008          98.000000                80
# 4          2014          94.000000                80

# %%
print(data.columns)
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
rating_mapping = {'TV-MA':9, 'R':10, 'NR':0, 'UR':11, 'TV-14':4, 'PG-13':5, 'TV-PG':12, 'PG':6, 'TV-Y7':1, 'TV-Y7-FV':7, 'TV-Y':2, 'TV-G':8, 'G':3}
data['rating'] = data['rating'].map(rating_mapping)

# %%
import numpy as np
import scipy as sp
data.dropna(subset=['ratingLevel'])
# Out:
#                                           title  rating  \
# 0                                  White Chicks       5
# 1                           Lucky Number Slevin      10
# 2                                Grey's Anatomy       4
# 3                                  Prison Break       4
# 4                         How I Met Your Mother      12
# 5                                  Supernatural       4
# 6                                  Breaking Bad       9
# 7                           The Vampire Diaries       4
# 8                              The Walking Dead       9
# 9                           Pretty Little Liars       4
# 10                             Once Upon a Time      12
# 11                                     Sherlock       4
# 12                                   Death Note       4
# 13                                       Naruto      12
# 14                                   The Hunter      10
# 15                        Lottie Dottie Chicken       2
# 16                                        Arrow       4
# 17                                 Black Mirror       9
# 18                                The Originals       4
# 19                                      The 100       0
# 20                           Masha and the Bear       2
# 21                      Ó Pai, Ó - Look at This       9
# 22                       Nymphomaniac: Volume 1       0
# 23                       Hunter X Hunter (2011)       0
# 24                           Marvel's Luke Cage       9
# 25                           Marvel's Iron Fist       9
# 26                                       Narcos       9
# 27                                    The Flash      12
# 28                        The Seven Deadly Sins       4
# 29                                       Scream       4
# ..                                          ...     ...
# 970                                       Annie       6
# 971          An American Tail: Fievel Goes West       3
# 972                        D2: The Mighty Ducks       6
# 973                    Honey, I Shrunk the Kids       6
# 974                              The Iron Giant       6
# 975                     The Fox and the Hound 2       3
# 976                                 Air Buddies       6
# 977             Dr. Dolittle: Tail to the Chief       6
# 978                                    Flicka 2       6
# 979                         H2O: Just Add Water      12
# 980                                The Gruffalo       2
# 981                                Dolphin Tale       6
# 982                               Pound Puppies       2
# 983  Beverly Hills Chihuahua 3: Viva La Fiesta!       3
# 984                        The Magic School Bus       2
# 985                                   Step Dogs      12
# 986                      Pokémon: Indigo League       2
# 987                                  Mia and Me       2
# 988                                  Paddington       6
# 989                             Russell Madness       6
# 990                           My Animal Friends       2
# 991                          Dawn of the Croods       1
# 992                  Alpha and Omega: Dino Digs       8
# 993                   Wiener Dog Internationals       3
# 994                                    Pup Star       3
# 995                                     The BFG       6
# 996                     The Secret Life of Pets       6
# 997                            Precious Puppies       8
# 998                                 Beary Tales       8
# 999                             Growing Up Wild       3
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# 5    Parents strongly cautioned. May be unsuitable ...                 90
# 6    For mature audiences.  May not be suitable for...                110
# 7    Parents strongly cautioned. May be unsuitable ...                 90
# 8    For mature audiences.  May not be suitable for...                110
# 9    Parents strongly cautioned. May be unsuitable ...                 90
# 10   Parental guidance suggested. May not be suitab...                 70
# 11   Parents strongly cautioned. May be unsuitable ...                 90
# 12   Parents strongly cautioned. May be unsuitable ...                 90
# 13   Parental guidance suggested. May not be suitab...                 70
# 14                         language and brief violence                100
# 15                              Suitable for all ages.                 10
# 16   Parents strongly cautioned. May be unsuitable ...                 90
# 17   For mature audiences.  May not be suitable for...                110
# 18   Parents strongly cautioned. May be unsuitable ...                 90
# 19                      This movie has not been rated.                124
# 20                              Suitable for all ages.                 10
# 21   For mature audiences.  May not be suitable for...                110
# 22                      This movie has not been rated.                124
# 23                      This movie has not been rated.                124
# 24   For mature audiences.  May not be suitable for...                110
# 25   For mature audiences.  May not be suitable for...                110
# 26   For mature audiences.  May not be suitable for...                110
# 27   Parental guidance suggested. May not be suitab...                 70
# 28   Parents strongly cautioned. May be unsuitable ...                 90
# 29   Parents strongly cautioned. May be unsuitable ...                 90
# ..                                                 ...                ...
# 970                     adult content and mld violence                 60
# 971          General Audiences. Suitable for all ages.                 35
# 972         some mild language and rough hockey action                 60
# 973  Parental guidance suggested. May not be suitab...                 60
# 974                   fantasy action and mild language                 60
# 975          General Audiences. Suitable for all ages.                 35
# 976                              some mild, rude humor                 60
# 977         brief mild language and some rude behavior                 60
# 978                             some reckless behavior                 60
# 979  Parental guidance suggested. May not be suitab...                 70
# 980                             Suitable for all ages.                 10
# 981                        some mild thematic elements                 60
# 982                             Suitable for all ages.                 10
# 983          General Audiences. Suitable for all ages.                 35
# 984                             Suitable for all ages.                 10
# 985  Parental guidance suggested. May not be suitab...                 70
# 986                             Suitable for all ages.                 10
# 987                             Suitable for all ages.                 10
# 988                         mild action and rude humor                 60
# 989                  some rude humor and sports action                 60
# 990                             Suitable for all ages.                 10
# 991             Suitable for children ages 7 and older                 41
# 992                             Suitable for all ages.                 35
# 993          General Audiences. Suitable for all ages.                 35
# 994          General Audiences. Suitable for all ages.                 35
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999          General Audiences. Suitable for all ages.                 35
#
#      release year  user rating score  user rating size
# 0            2004          82.000000                80
# 1            2006          84.094215                82
# 2            2016          98.000000                80
# 3            2008          98.000000                80
# 4            2014          94.000000                80
# 5            2016          95.000000                80
# 6            2013          97.000000                80
# 7            2017          91.000000                80
# 8            2015          98.000000                80
# 9            2016          96.000000                80
# 10           2016          98.000000                80
# 11           2016          95.000000                80
# 12           2006          77.000000                80
# 13           2008          88.000000                80
# 14           2011          84.094215                82
# 15           2009          84.094215                82
# 16           2015          96.000000                80
# 17           2016          80.000000                80
# 18           2016          74.000000                80
# 19           2016          97.000000                80
# 20           2013          81.000000                80
# 21           2007          84.094215                82
# 22           2013          84.094215                82
# 23           2013          57.000000                80
# 24           2016          95.000000                80
# 25           2017          98.000000                80
# 26           2016          94.000000                80
# 27           2016          98.000000                80
# 28           2016          84.094215                82
# 29           2016          84.094215                82
# ..            ...                ...               ...
# 970          1982          68.000000                80
# 971          1991          84.094215                82
# 972          1994          70.000000                80
# 973          1989          80.000000                80
# 974          1999          83.000000                80
# 975          2006          84.094215                82
# 976          2006          84.094215                82
# 977          2008          84.094215                82
# 978          2010          84.094215                82
# 979          2009          74.000000                80
# 980          2009          84.094215                82
# 981          2011          84.094215                82
# 982          2013          84.094215                82
# 983          2012          84.094215                82
# 984          1997          81.000000                80
# 985          2013          84.094215                82
# 986          2000          74.000000                80
# 987          2015          84.094215                82
# 988          2014          70.000000                80
# 989          2015          84.094215                82
# 990          2013          84.094215                82
# 991          2017          72.000000                80
# 992          2016          84.094215                82
# 993          2015          84.094215                82
# 994          2016          84.094215                82
# 995          2016          97.000000                80
# 996          2016          84.094215                81
# 997          2003          84.094215                82
# 998          2013          84.094215                82
# 999          2016          80.000000                80
#
# [1000 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null int64
# ratingLevel          1000 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    1000 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 54.8+ KB

# %%
for i in range(1,1001):
    kwargs = { 'score_size': lambda x: (x['user rating score'])/x['user rating size']}
    data= data.assign(**kwargs)
data.head()
# Out:
#                    title  rating  \
# 0           White Chicks       5
# 1    Lucky Number Slevin      10
# 2         Grey's Anatomy       4
# 3           Prison Break       4
# 4  How I Met Your Mother      12
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size  score_size
# 0          2004          82.000000                80    1.025000
# 1          2006          84.094215                82    1.025539
# 2          2016          98.000000                80    1.225000
# 3          2008          98.000000                80    1.225000
# 4          2014          94.000000                80    1.175000

# %%
from textblob import TextBlob

# %%
def textsubjectivity(Text):
    a = TextBlob(Text)
    b = a.sentiment.polarity
    sub = a.sentiment.subjectivity
    return sub

# %%
def textpolarity(Text):
    a = TextBlob(Text)
    pol = a.sentiment.polarity
    return pol

# %%
subar=[]
polar=[]
for i in range(0,1000):
    Text = data['ratingLevel'][i]
    s = textsubjectivity(Text)
    subar.append(s)
    p = textpolarity(Text)
    polar.append(p)

# %%
subar = np.asarray(subar)
polar = np.asarray(polar)
for i in range(0,1000):
#     print(subar[i])
     data['tsub'][i] = subar[i]
#     print(data['tsub'][i])
data.head()
# Out:
# C:\Users\PRIYANSHU SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                    title  rating  \
# 0           White Chicks       5
# 1    Lucky Number Slevin      10
# 2         Grey's Anatomy       4
# 3           Prison Break       4
# 4  How I Met Your Mother      12
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size  score_size      tsub
# 0          2004          82.000000                80    1.025000  0.916667
# 1          2006          84.094215                82    1.025539  0.622222
# 2          2016          98.000000                80    1.225000  0.733333
# 3          2008          98.000000                80    1.225000  0.733333
# 4          2014          94.000000                80    1.175000  0.750000

# %%
for i in range(0,1000):
#     print(polar[i])
     data['tpol'][i] = polar[i]
#    print(data['tpol'][i])
data.head()
# Out:
# C:\Users\PRIYANSHU SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                    title  rating  \
# 0           White Chicks       5
# 1    Lucky Number Slevin      10
# 2         Grey's Anatomy       4
# 3           Prison Break       4
# 4  How I Met Your Mother      12
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size  score_size      tsub  \
# 0          2004          82.000000                80    1.025000  0.916667
# 1          2006          84.094215                82    1.025539  0.622222
# 2          2016          98.000000                80    1.225000  0.733333
# 3          2008          98.000000                80    1.225000  0.733333
# 4          2014          94.000000                80    1.175000  0.750000
#
#        tpol
# 0 -0.100000
# 1  0.344444
# 2  0.433333
# 3  0.433333
# 4  0.550000

# %%
del data['f_class']
data.head()
# Out:
#                    title  rating  \
# 0           White Chicks       5
# 1    Lucky Number Slevin      10
# 2         Grey's Anatomy       4
# 3           Prison Break       4
# 4  How I Met Your Mother      12
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size  score_size      tsub  \
# 0          2004          82.000000                80    1.025000  0.916667
# 1          2006          84.094215                82    1.025539  0.622222
# 2          2016          98.000000                80    1.225000  0.733333
# 3          2008          98.000000                80    1.225000  0.733333
# 4          2014          94.000000                80    1.175000  0.750000
#
#        tpol               class
# 0 -0.100000  Parential Guidance
# 1  0.344444        For Above 17
# 2  0.433333  Parential Guidance
# 3  0.433333  Parential Guidance
# 4  0.550000        For Above 17

# %%
data.to_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/LARGE SCALE DATA PROCESSING/PROJECT/netfli_main.csv')

# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
cols = ['rating', 'ratingDescription', 'release year', 'score_size', 'tsub' , 'tpol']
cm = np.corrcoef(data[cols].values.T)
sb.set(font_scale=1)
hm=sb.heatmap(cm,
               cbar=True,
               annot=True,
               square=True,
               fmt='.2f',
               annot_kws={'size':10},
               yticklabels=cols,
               xticklabels=cols)
plt.show()

# %%
data.loc[data['rating']<4,'class']= 'For All'
data.loc[((data['rating']>=4) & (data['rating']<9)),'class']= 'Parential Guidance'
data.loc[data['rating']>=9,'class']= 'For Above 17'

# %%
data.head()
# Out:
#                    title  rating  \
# 0           White Chicks       5
# 1    Lucky Number Slevin      10
# 2         Grey's Anatomy       4
# 3           Prison Break       4
# 4  How I Met Your Mother      12
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size  score_size      tsub  \
# 0          2004          82.000000                80    1.025000  0.916667
# 1          2006          84.094215                82    1.025539  0.622222
# 2          2016          98.000000                80    1.225000  0.733333
# 3          2008          98.000000                80    1.225000  0.733333
# 4          2014          94.000000                80    1.175000  0.750000
#
#        tpol               class  f_class
# 0 -0.100000  Parential Guidance        1
# 1  0.344444        For Above 17        2
# 2  0.433333  Parential Guidance        1
# 3  0.433333  Parential Guidance        1
# 4  0.550000        For Above 17        2

# %%
data.tail()
# Out:
#                        title  rating  \
# 995                  The BFG       6
# 996  The Secret Life of Pets       6
# 997         Precious Puppies       8
# 998              Beary Tales       8
# 999          Growing Up Wild       3
#
#                                            ratingLevel  ratingDescription  \
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999          General Audiences. Suitable for all ages.                 35
#
#      release year  user rating score  user rating size  score_size      tsub  \
# 995          2016          97.000000                80    1.212500  0.644444
# 996          2016          84.094215                81    1.038200  0.350000
# 997          2003          84.094215                82    1.025539  0.750000
# 998          2013          84.094215                82    1.025539  0.750000
# 999          2016          80.000000                80    1.000000  0.625000
#
#          tpol               class  f_class
# 995 -0.266667  Parential Guidance        1
# 996 -0.100000  Parential Guidance        1
# 997  0.550000  Parential Guidance        1
# 998  0.550000  Parential Guidance        1
# 999  0.300000             For All        0

# %%
from sklearn.cross_validation import train_test_split
X = data.iloc[:, [3,4,5,6,8,9]].values
X_train,X_test,y_train,y_test = train_test_split(X,data['class'], test_size=0.2, random_state=0)

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, gamma=.2, C=10.0)
svm.fit(X_train, y_train)
# Out:
# SVC(C=10.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.2, kernel='rbf',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svm.score(X_test, y_test, sample_weight=None)
# Out:
# 0.96999999999999997

# %%
comm = "Parental guidance suggested. May not be suitable for all children."
a = TextBlob(comm)
a_sub = a.sentiment.subjectivity
a_pol = a.sentiment.polarity
print(a_sub)
print(a_pol)
# Out:
# 0.75
# 0.55

# %%
x = [[74,2015,96,83,a_sub,a_pol]] 
svm.predict(x)
# Out:
# array(['Parential Guidance'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sb
cols = ['rating', 'ratingDescription', 'release year', 'score_size' , 'tsub' , 'tpol']

# %%
sb.pairplot(data.dropna(),hue='class')

# %%
plt.show()

# %%
from sklearn.cross_validation import train_test_split
X = data.iloc[:, [3,7]].values
X_train,X_test,y_train,y_test = train_test_split(X,data['class'], test_size=0.3, random_state=0)

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, gamma=.2, C=10.0)
svm.fit(X_train, y_train)
# Out:
# SVC(C=10.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.2, kernel='rbf',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svm.score(X_test, y_test, sample_weight=None)
# Out:
# 0.93000000000000005

# %%
print(data.columns)
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size', 'score_size', 'tsub', 'tpol',
#        'class'],
#       dtype='object')

# %%
#DECISION TREE

# %%
simple_mapping = {'For All':0, 'Parential Guidance':1, 'For Above 17':2}
data['f_class'] = data['class'].map(simple_mapping)
data.head()
# Out:
#                    title  rating  \
# 0           White Chicks       5
# 1    Lucky Number Slevin      10
# 2         Grey's Anatomy       4
# 3           Prison Break       4
# 4  How I Met Your Mother      12
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size  score_size      tsub  \
# 0          2004          82.000000                80    1.025000  0.916667
# 1          2006          84.094215                82    1.025539  0.622222
# 2          2016          98.000000                80    1.225000  0.733333
# 3          2008          98.000000                80    1.225000  0.733333
# 4          2014          94.000000                80    1.175000  0.750000
#
#        tpol               class  f_class
# 0 -0.100000  Parential Guidance        1
# 1  0.344444        For Above 17        2
# 2  0.433333  Parential Guidance        1
# 3  0.433333  Parential Guidance        1
# 4  0.550000        For Above 17        2

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
columns = ['ratingDescription', 'release year','score_size', 'tsub', 'tpol']
X_train,X_test,Y_train,Y_test = train_test_split(data[columns],data['class'],test_size=0.2,random_state=14)
tree = DecisionTreeClassifier(max_depth=7,random_state=0)
tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=7,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
print("Accuracy on the training set: %.3f" % tree.score(X_train,Y_train))
print("Accuracy on the testing set: %.3f" % tree.score(X_test,Y_test))
# Out:
# Accuracy on the training set: 1.000
# Accuracy on the testing set: 0.995

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file="tree.dot", class_names=['1','2','3'], impurity=False, filled=True,
                feature_names=data[columns].columns)

# %%
import graphviz

# %%
with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split

feat_labels = data.columns[[3,4,7,8,9]]
forest = RandomForestClassifier(n_estimators=10000,random_state=0,n_jobs=-1)
forest.fit(X_train, Y_train)
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(0,5):
    print("%2d) %-*s %f" % (f + 1, 30,feat_labels[f],importances[indices[f]]))
# Out:
#  1) ratingDescription              0.360214
#  2) release year                   0.315344
#  3) score_size                     0.102941
#  4) tsub                           0.095240
#  5) tpol                           0.094350

# %%
import matplotlib.pyplot as plt
plt.title('Feature Importances')
plt.bar(range(X_train.shape[1]),importances[indices],color='darkred',align='center')
plt.xticks(range(X_train.shape[1]),feat_labels, rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
plt.figure(figsize=(8,6))
plt.show()

# %%
columns = ['ratingDescription', 'score_size']
X_train,X_test,Y_train,Y_test = train_test_split(data[columns],data['f_class'],test_size=0.2,random_state=14)
data.head()
# Out:
#                    title  rating  \
# 0           White Chicks       5
# 1    Lucky Number Slevin      10
# 2         Grey's Anatomy       4
# 3           Prison Break       4
# 4  How I Met Your Mother      12
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size  score_size      tsub  \
# 0          2004          82.000000                80    1.025000  0.916667
# 1          2006          84.094215                82    1.025539  0.622222
# 2          2016          98.000000                80    1.225000  0.733333
# 3          2008          98.000000                80    1.225000  0.733333
# 4          2014          94.000000                80    1.175000  0.750000
#
#        tpol               class  f_class
# 0 -0.100000  Parential Guidance        1
# 1  0.344444        For Above 17        2
# 2  0.433333  Parential Guidance        1
# 3  0.433333  Parential Guidance        1
# 4  0.550000        For Above 17        2

# %%
from sklearn.neighbors import KNeighborsClassifier
training_accuracy = []
test_accuracy = []

# tryning n_neighbours from 1 to 10

neighbors_settings = range(1,12)
for n_neighbors in neighbors_settings:
    # building the model
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(X_train, Y_train)
    # recording the training set accuracy
    training_accuracy.append(knn.score(X_train, Y_train))
    # testing accuracy
    test_accuracy.append(knn.score(X_test, Y_test))
    
plt.plot(neighbors_settings, training_accuracy, label="training accuracy")
plt.plot(neighbors_settings, test_accuracy, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()
plt.savefig("knn_compare_model")
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,Y_train)

print('Accuracy of k-NN classifier on the training set:{:.2f}'.format(knn.score(X_train, Y_train)))
print('Accuracy of k-NN classifier on the testing set:{:.2f}'.format(knn.score(X_test, Y_test)))
# Out:
# Accuracy of k-NN classifier on the training set:0.96
# Accuracy of k-NN classifier on the testing set:0.96

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
# title                1000 non-null object
# rating               1000 non-null int64
# ratingLevel          1000 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    1000 non-null float64
# user rating size     1000 non-null int64
# score_size           1000 non-null float64
# tsub                 1000 non-null float64
# tpol                 1000 non-null float64
# class                1000 non-null object
# f_class              1000 non-null int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 93.8+ KB

# %%
#LINEAR REGRESSION

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression

# %%
X = data[['ratingDescription', 'release year', 'user rating score', 'user rating size', 'tsub', 'tpol']].values
Y = data[['f_class']].values

# %%
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regr.coef_ #slope
# Out:
# array([[ 0.01507378,  0.01095848,  0.00099802, -0.03226266, -0.08944526,
#          0.29724204]])

# %%
regr.intercept_ #intercept
# Out:
# array([-19.59948199])

# %%
print('Slope: %.3f' % regr.coef_[0][0])
print('Intercept: %.3f' % regr.intercept_[0])
# Out:
# Slope: 0.015
# Intercept: -19.599

# %%
comm = "Parental guidance suggested. May not be suitable for all children."
a = TextBlob(comm)
a_sub = a.sentiment.subjectivity
a_pol = a.sentiment.polarity
print(a_sub)
print(a_pol)
# Out:
# 0.75
# 0.55

# %%
x = [[70,2016,98,80,a_sub,a_pol]]

# %%
class_std = regr.predict(x)
print("CLASS: %.3f" %class_std)
# Out:
# CLASS: 1.161
